# %% [markdown]
# # Log notebook

# %% [markdown]
# ## 2024/1/13 (Fix few bugs in dynamics and controller)

# %% [markdown]
# #### MPPI

# %% [markdown]
# 1) Counter Oval
#     - data/data-20240113-202130
#
# 2) Oval
#     - (untuned) data/data-20240113-202923
#     - data/data-20240113-203647
#
# 3) Circle
#     - data/data-20240113-204955
#
# 4) Counter Circle
#     - data/data-20240113-205528
#
# 5) Straight Line
#     - data/data-20240113-210901
#     - data/data-20240113-211256
#     - data/data-20240113-211613

# %% [markdown]
# #### PID

# %% [markdown]
# 1) Counter Oval
#    - (discounted) data/data-20240113-212753
#    - (discounted) data/data-20240113-213104
#
# 3) Oval
#    - data/data-20240113-213303
#
# 5) Circle
#     - data/data-20240113-213741
#
# 7) Counter Circle
#     - data/data-20240113-212207
#
# 8) Straight Line
#     - data/data-20240113-211821
#     - data/data-20240113-212006
#     - data/data-20240113-212055

# %% [markdown]
# ---

# %% [markdown]
# # Previous Logs

# %% [markdown]
# ###  (PID)
# > Counter circle
# - data/data-20240105-014821
# - data/data-20240105-014945
# - data/data-20240105-015029
# - data/data-20240105-015117
# - data/data-20240105-015156
# - data/data-20240105-015233
# - data/data-20240105-015306
# - data/data-20240105-015438
# - data/data-20240105-015408
# - data/data-20240105-015547
#
# (b) Counter (10 rounds)
# - data/data-20240105-175308
#
# (c) Clockwise (10 rounds)
# - data/data-20240105-175630
#
#
# > Circle
#
# ## MPPI
#
# ### Line
#
# (a) Straight
# - data/data-20240105-131330
# - data/data-20240105-131642
# - data/data-20240105-131554
#
# (b) Arc left
# - data/data-20240105-132023
# - data/data-20240105-132200
# - data/data-20240105-132304
#
# (c) Arc right
# - data/data-20240105-132434
# - data/data-20240105-132718
# - data/data-20240105-133440
#
# ### Circle
#
# #### 8/32 waypoints
# (a) counter (10 rounds)
# - data/data-20240105-150914
# - data/data-20240105-151205
# - (test) data/data-20240105-185035
# - (test) data/data-20240105-185247
# - (test) data/data-20240105-190519
# - (N) data/data-20240105-190740
# - (N) data/data-20240105-191109
# - (N) data/data-20240105-191404
#
# (b) clockwise (10 rounds)
# - (test) data/data-20240105-151616
# - (test) data/data-20240105-151931
# - (test) data/data-20240105-152139
# - (test) data/data-20240105-152431
# - (test) data/data-20240105-153650
# - (test) data/data-20240105-154351
# - (test) data/data-20240105-155543
# - (test) data/data-20240105-160156
# - (test) data/data-20240105-160427
# - (test) data/data-20240105-160800
# - (test) data/data-20240105-162551
# - (test) data/data-20240105-163849
# - (tset) data/data-20240105-164406
# - (test) data/data-20240105-165001
# - (test) data/data-20240105-170102
# - (test) data/data-20240105-165950
# - data/data-20240105-171153
# - (test) data/data-20240105-171705
# - (test) data/data-20240105-172938
# - (N) data/data-20240105-191841
# - (N) data/data-20240105-192140
# - (N) data/data-20240105-192859
#
#
# # Benchmarking
# (64 waypoints)
#
# ## Pure Car
#
# ### MPPI
# (a) clockwise (~10 rounds)
# - data/data-20240105-193158
# - data/data-20240105-193455
#
# (b) counter-clockwise (~10 rounds)
# - data/data-20240105-193808
# - data/data-20240105-194127
#
# ### PID
# (a) clockwise (~10 rounds)
# - data/data-20240105-195120
# - data/data-20240105-195435
#
# (b) counter-clockwise (~10rounds)
# - data/data-20240105-194503
# - data/data-20240105-194725
#
# ## Harmmer Car
#
# ### MPPI
# (a) clockwise
# - (not working) data/data-20240105-202100
# - (not working) data/data-20240105-202357
# - (not working) data/data-20240105-202642
#
# (b) counter clockwise
# - (not working) data/data-20240105-201236
# - data/data-20240105-201542
# - (not working) data/data-20240105-201842
#
#
# ### PID
# (a) clockwise
# - data/data-20240105-195939
# - data/data-20240105-200310
#
# (b) counter clockwise
# - data/data-20240105-200656
# - data/data-20240105-200926
#
#
#
# ## Continuous Tracking Reference
#
# ### MPPI
# clock
# - data/data-20240110-191657
# - data/data-20240110-192222
#
# counter clock
# - (test, H=5) data/data-20240110-193433
# - (test, H=3) data/data-20240110-201849
# - (test, H=4) data/data-20240110-203742
# - (test, H=4) data/data-20240110-204413
# - (test) data/data-20240110-205406
# - (test, H=5) data/data-20240110-210109
# - (test, H=7) data/data-20240110-211445
# - data/data-20240110-215325
# - data/data-20240110-220044
#
#
# ### PID
# Clock
# - data/data-20240110-192805
#
# counter clock
# - (test, action mag 1.0) data/data-20240110-194000
# - (test, action mag 1.1) data/data-20240110-194741
# - (test, action mag 1.5) data/data-20240110-195242
# - (test, action mag 1.8) data/data-20240110-195804
# - (test, tune pid) data/data-20240110-200153
# - (test, tune pid) data/data-20240110-200527
# - data/data-20240110-201103
# - data/data-20240110-203154
#
# ## DEBUG Yaw angle
#
#
# - [0.1, -1] data/data-20240110-230803
# - [0.1, -.75] data/data-20240110-235553
# - [0.1, -.74] data/data-20240111-181300
# - [0.1, -.715] data/data-20240111-183142
# - [0.1, -.7] data/data-20240111-180438
# - [0.1, -.5] data/data-20240111-180027
# - [0.1, -0.0575] data/data-20240111-182234
# - [0.1, 1] data/data-20240111-000040
# - [0.1, .75] data/data-20240111-000654
# - [0.1, .7] data/data-20240111-001742
# - [0.1, .65] data/data-20240111-002027
# - [0.1, .64] data/data-20240111-002624
# - [0.1, .635] data/data-20240111-003204
# - [0.1, .63] data/data-20240111-181759
# - [0.1, .625] data/data-20240111-002343
# - [0.1, .6] data/data-20240111-001333
# - [0.1, .5] data/data-20240111-000920
#
# ## DEBUG Yaw Angle
#
# - [0.1, -1] data/data-20240112-232036
# - [0.1, -0.86] data/data-20240112-233431
# - [0.1, -0.85] data/data-20240112-233212
# - [0.1, -0.8] data/data-20240112-233808
# - [0.1, -0.75] data/data-20240112-232743
# -
# - [0.1, 1.] data/data-20240112-232345
# - [0.1, 0.635]
#
#
# ## 2024/1/11
#
# ## Circle
#
# PID
# ### clock
# - data/data-20240111-203954
# -
# ### counter clock
# - data/data-20240111-204512
#
# mppi
# clock
#
# counter clock
# ## Oval
#
# PID
# Clock
# - data/data-20240111-203044
#
# ## 2024/1/12 (Multiple waypoints to MPPI)
#
# ### MPPI
# #### clock
# - data/data-20240112-165825
#
# #### Counter Clock
# - data/data-20240112-170404
#
# #### Oval
# - data/data-20240112-171448
# - data/data-20240112-171828
# - data/data-20240112-213438
#
# #### Counter Oval
# - data/data-20240112-172318
#
# ### PID
#
#
# #### Oval
# - data/data-20240112-174353
# - data/data-20240112-212710
# -
# ####  Counter Oval
# - data/data-20240112-173437

# %% [markdown]
# ## 2024/1/18 Learned Dynamics + MPPI
#
# Collect Training Data (8Hz)
#
# A. PID
#     1. Circle
#         - data/data-20240118-140821
#     2. Counter Circle
#         - data/data-20240118-141403
#
# B. MPPI-KBM
#     1. Circle
#         - data/data-20240118-142356
#     2. Counter Circle
#         - data/data-20240118-141930
#
# ERROR MPPI-nn data
#
# - data/data-20240118-235203

# %% [markdown]
# # 2024/1/20 Sim Data Train NN
#
# 1) circle
# - data/sim-data-20240120-221125
# 2) counter circle
# - data/sim-data-20240120-220549

# %% [markdown]
# # 2024/1/21 Real
#
# Circle, PID
# - data/data-20240121-200653 [0, 128]
#
# Circle, MPPI-KBM
# - data/data-20240121-202556 [0, 56]
# - data/data-20240121-203153 [0, 77]
# - data/data-20240121-203555 [0, 133] perfect tracking
# - data/data-20240121-205544 [0, 461] data for training
# - data/data-20240121-212846 [0, 298] data for training
# Circle, MPPI-NN
# - data/data-20240121-204847
# - data/data-20240121-220444
# - data/data-20240121-221249 [30, 37] fail data for training
# - data/data-20240121-222525 [30, 38] fail data for training
# - data/data-20240121-222819 [30, 37] fail data for training
# - data/data-20240121-224929 [30, 37] fail data for testing
# - data/data-20240121-225219 [30, 37] fail data for testing

# %% [markdown]
# # 2024/1/24
#
# ## Real Random Data
#
# - data/data-20240124-161549 [0, 142]
# - data/data-20240124-162031 [0, 213]
# - data/data-20240124-163435 [0, 221]
# - data/data-20240124-164004 [0, 239]
# - data/data-20240124-164815 [0, 378]
# - data/data-20240124-165725 [0, 296]
# - data/data-20240124-170503 [0, 133]
#
# ## Real NN Data
#
# - (old model) data/data-20240124-224232 [0, 41] fail data
# - (new model) data/data-20240124-224614 [0, 108] circle
# - data/data-20240124-231451 [0, 208] circle
# - data/data-20240124-230330 [0, 42] counter circle
# - data/data-20240124-231045 [0, 43] counter circle
#
# # 2024/1/28
#
# a) train in sim, eval in real
# - (end2end 20240128-190950) data/data-20240128-200647 [0, 265] circle
# - (end2end 20240128-192226) data/data-20240128-202220 [0, 421] circle
# - (end2end 20240128-193512) data/data-20240128-203539 [] fail circle
# - (end2end 20240127-232603) data/data-20240128-222727 [] circle
# - (end2end 20240127-232603) data/data-20240128-223809 [0, 153] counter circle
#
# b) train in real, eval in real
# - (end2end 20240128-114748) data/data-20240128-205558 [0, 112] circle
# - (end2end 20240128-114748) data/data-20240128-210705 [0, 41] vicon got lost
# - (end2end 20240128-114748) data/data-20240128-211523 circle
# - (end2end 20240128-114748) data/data-20240128-221820 circle
# - (end2end 20240128-114748) data/data-20240128-224707 counter circle
# - (end2end 20240128-114748) data/data-20240128-225753 counter circle
# - (kbm, with recover) data/data-20240128-221306 [0, 152] circle
#
# Terrain (Partial 50%)
#
# - (pid) data/data-20240129-000528 [0,  109] circle
# - (mppi-kbm) data/data-20240128-235759 [0, 80] circle
# - (mppi-kbm) data/data-20240129-000933 [0, 697] circle for training
# - (end2end 20240127-232603) data/data-20240129-005540 [0,155] circle
# - (end2end 20240128-114748) data/data-20240129-010235 [0, 90] circle
# - (end2end 20240129-010640) data/data-20240129-011043
# - (end2end 20240129-010916) data/data-20240129-011800
# - (end2end 20240129-012124) data/data-20240129-012626
# - () data/data-20240129-013608
# - (end2end 20240129-014709) data/data-20240129-015032

# %% [markdown]
# ## 2024/1/30
#
# a) Teleop data
# - data-20240130-230806 [0, 156]
# - data-20240130-231331 [0, 124]
# - data-20240130-231613 [0, 198]
# - data-20240130-231924 [0, 202]
# - data-20240130-232244 [0, 525]
# - data-20240130-232853 [0, 321]
#
# b) Sim data
# - sim-data-20240131-134617 [0, 1]

# %% [markdown]
# # 2024/1/31
#
# ## No disturbance
#
# ### Track circle
#
# a) mppi-kbm
# - data/data-20240131-184333 [0, 91]
# b) mppi-nn-end2end (sim)
# - data/data-20240131-185608 [0, 335]
# c) mppi-nn-end2end (real)
# - data/data-20240131-190102 fail
# d) mppi-nn-end2end (mix)
# - data/data-20240131-190957 [0, 246]
# e) pid
# - data/data-20240131-191359 [0, 146]
#
# ### Track counter-circle
#
# a) mppi-kbm
# - data/data-20240131-184835 [0, 178]
#
# b) mppi-nn-end2end (sim)
# - data/data-20240131-185315 [0, 135]
#
# c) mppi-nn-end2end (real)
# - data/data-20240131-190328 fail
#
# d) mppi-nn-end2end (mix)
# - data/data-20240131-190510 [0, 313]
# e) pid
# - data/data-20240131-191625 [0, 174]
#
# ## Tie bat (3 layers)
#
# ### Track circle
# a) pid
# - data/data-20240131-195456 [0, 248]
#
# b) mppi-kbm
# - data/data-20240131-195144 [0, 258]
#
# c) mppi-end2end (sim)
# - data/data-20240131-194852 [0, 229]
#
# ### Track counter-circle
#
# a) pid
# - data/data-20240131-193447 [0, 190]
# - data/data-20240131-193753 [0, 124]
#
# b) mppi-kbm
# - data/data-20240131-194101 [0, 207]
#
# c) mppi-end2end (sim)
# - data/data-20240131-194454 [0, 249]
#
# ### Random Teleop Data
# - data-20240131-231825 [0, 287]
# - data-20240131-232317 [0, 255]
# - data-20240131-232820 [0, 24]
# - data-20240131-233023 [0, 25]
# - data-20240131-233226 [0, 29]
# - data-20240131-234418 [0, 362]
# - data-20240131-235043 [0, 24]

# %%
# 2024/2/1

## Random Data
- data-20240201-200427 [0, 480] 2k
- data-20240201-202035 [0, 489] 2k
- data-20240201-221923 [0, 689] 3k
## NN-REAL
- data/data-20240201-204220


# 2024/2/3

## MPPI-kbm circle

- data/data-20240203-151742 [0, 219]
- data/data-20240203-152221 [0, 143]

## MPPI-NN-END2END-TRUNK circle
(mix)
- data/data-20240203-153246 [0, 127]
(sim)
- data/data-20240203-153613 [0, 127]
(real)
- data/data-20240203-153846 [0, 68] fail

## DRAG MPPI-NN-END2END-TRUNK circle

(mix-nondrag)
- data/data-20240203-155320 [0, 163]

(mix-drag)
- data/data-20240203-155656 [0, 276]

(mix-drag h8)
- data/data-20240203-160111 [0, 147]


## MPPI larger circle
(kbm)
- data/data-20240203-160416

(phyx-kbm)
- data/data-20240203-172021

(end2end-trunk, real)
- data/data-20240203-172419 [0, 201]

(end2end-trunk, mix)
- data/data-20240203-172827

(end2end-trunk, sim)
- data/data-20240203-173550 

## MPPI oval
(kbm)
- data/data-20240203-180203 [0, 109]
- data/data-20240203-180443 [0, 78]

(end2end-trunk, sim)
- data/data-20240203-175241 [0, 200]

(end2end-trunk, real)
- data/data-20240203-175725 [0, 142]
